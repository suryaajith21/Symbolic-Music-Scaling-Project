# %%
from google.colab import drive
drive.mount("/content/drive")

import os
PROJECT_DIR = "/content/drive/MyDrive/MusicScalingProject"
print("PROJECT_DIR exists?", os.path.exists(PROJECT_DIR))
print("PROJECT_DIR contents:", os.listdir(PROJECT_DIR))

print("data folder contents:", os.listdir(os.path.join(PROJECT_DIR, "data")))
print("data/v3 contents:", os.listdir(os.path.join(PROJECT_DIR, "data", "v3")))
print("src contents:", os.listdir(os.path.join(PROJECT_DIR, "src")))
# Out:
# Mounted at /content/drive
# PROJECT_DIR exists? True
# PROJECT_DIR contents: ['src', 'data', 'results', 'checkpoints_rnn']
# data folder contents: ['processed', 'checkpoints', 'processed_v2', 'checkpoints_best', 'v3']
# data/v3 contents: ['tokenizer_bpe_4096.json', 'train.bin', 'val.bin', 'test.bin']
# src contents: ['model.py', '__pycache__', 'train_scaling.py', 'finish_xl.py', 'model_rnn.py', 'config_rnn.py', 'train_rnn.py', 'finish_rnn_xl.py', 'generate.py', 'evaluate_best.py', 'config.py']

# %%
# !pip -q install tokenizers

# %%
import shutil, os
PROJECT_DIR = "/content/drive/MyDrive/MusicScalingProject"

src_model = os.path.join(PROJECT_DIR, "src", "model.py")
dst_model = "/content/model.py"
shutil.copyfile(src_model, dst_model)
print("Copied:", src_model, "->", dst_model)
# Out:
# Copied: /content/drive/MyDrive/MusicScalingProject/src/model.py -> /content/model.py

# %%
# %%writefile /content/train_v3_drive.py
from __future__ import annotations

import os, time, math, json, random
from dataclasses import dataclass, asdict
from pathlib import Path

import numpy as np
import torch
import torch.nn as nn
from torch.optim import AdamW
from tokenizers import Tokenizer

from model import GPT  




PROJECT_DIR = Path("/content/drive/MyDrive/MusicScalingProject")
DATA_DIR = PROJECT_DIR / "data" / "v3"   
TOK_JSON = DATA_DIR / "tokenizer_bpe_4096.json"
TRAIN_BIN = DATA_DIR / "train.bin"
VAL_BIN   = DATA_DIR / "val.bin"

RUN_NAME = "V3_best_150M"
RUN_DIR = PROJECT_DIR / "runs" / RUN_NAME
CKPT_DIR = RUN_DIR / "checkpoints"
SAMPLE_DIR = RUN_DIR / "samples"
RUN_DIR.mkdir(parents=True, exist_ok=True)
CKPT_DIR.mkdir(parents=True, exist_ok=True)
SAMPLE_DIR.mkdir(parents=True, exist_ok=True)

METRICS_JSONL = RUN_DIR / "metrics.jsonl"
CONFIG_JSON   = RUN_DIR / "run_config.json"




@dataclass
class ModelConfig:
    n_layer: int = 16
    n_head: int = 16
    n_embd: int = 1024
    block_size: int = 1024
    vocab_size: int = 4096
    dropout: float = 0.1

CFG = ModelConfig()




DEVICE = "cuda"
DTYPE = torch.bfloat16  

MICRO_BSZ = 16
GRAD_ACCUM = 4
BLOCK_SIZE = CFG.block_size

MAX_STEPS = 20000  
LR = 3e-4
MIN_LR = 3e-5
WARMUP_STEPS = 200
WEIGHT_DECAY = 0.1
BETAS = (0.9, 0.95)
GRAD_CLIP = 1.0

LOG_INTERVAL = 20
EVAL_INTERVAL = 200
EVAL_ITERS = 200
CKPT_INTERVAL = 500
SAMPLE_INTERVAL = 500


GEN_PROMPT_TOKENS = 256
GEN_NEW_TOKENS = 1024
TEMPERATURE = 1.0
TOP_K = 200
STOP_AT_EOT = True

SEED = 1337

DELIM = "<|endoftext|>"

def set_seed(seed: int):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

def cosine_lr(step: int) -> float:
    if step < WARMUP_STEPS:
        return LR * (step + 1) / WARMUP_STEPS
    progress = min(1.0, (step - WARMUP_STEPS) / max(1, (MAX_STEPS - WARMUP_STEPS)))
    coeff = 0.5 * (1.0 + math.cos(math.pi * progress))
    return MIN_LR + coeff * (LR - MIN_LR)

class BinDataset:
    def __init__(self, path: Path):
        self.data = np.memmap(path, dtype=np.uint16, mode="r")
        self.n = len(self.data)

    def get_batch(self, batch_size: int, block_size: int, device: str):
        ix = np.random.randint(0, self.n - block_size - 1, size=(batch_size,))
        x = np.stack([self.data[i:i+block_size].astype(np.int64) for i in ix])
        y = np.stack([self.data[i+1:i+1+block_size].astype(np.int64) for i in ix])
        x = torch.from_numpy(x).to(device, non_blocking=True)
        y = torch.from_numpy(y).to(device, non_blocking=True)
        return x, y

@torch.no_grad()
def estimate_loss(model: nn.Module, val_ds: BinDataset) -> float:
    model.eval()
    losses = []
    for _ in range(EVAL_ITERS):
        x, y = val_ds.get_batch(MICRO_BSZ, BLOCK_SIZE, DEVICE)
        with torch.autocast(device_type="cuda", dtype=DTYPE):
            _, loss = model(x, y)
        losses.append(loss.item())
    model.train()
    return float(np.mean(losses))

def save_jsonl(path: Path, record: dict):
    with path.open("a", encoding="utf-8") as f:
        f.write(json.dumps(record) + "\n")

def save_checkpoint(model, optim, step: int, best_val):
    path = CKPT_DIR / f"ckpt_step_{step:07d}.pt"
    torch.save({
        "step": step,
        "model": model.state_dict(),
        "optim": optim.state_dict(),
        "cfg": asdict(CFG),
        "best_val": best_val,
    }, path)
    print(f"[CKPT] saved {path}")

@torch.no_grad()
def generate_sample(model: nn.Module, tok: Tokenizer, val_ds: BinDataset, step: int):
    model.eval()
    eot_id = tok.token_to_id(DELIM)
    assert eot_id is not None

    start = np.random.randint(0, val_ds.n - (GEN_PROMPT_TOKENS + 1))
    prompt_ids = val_ds.data[start:start+GEN_PROMPT_TOKENS].astype(np.int64).tolist()
    out = torch.tensor([prompt_ids], dtype=torch.long, device=DEVICE)

    for _ in range(GEN_NEW_TOKENS):
        out_cond = out[:, -BLOCK_SIZE:]
        with torch.autocast(device_type="cuda", dtype=DTYPE):
            logits, _ = model(out_cond)
        logits = logits[:, -1, :] / TEMPERATURE

        if TOP_K is not None:
            v, _ = torch.topk(logits, TOP_K)
            logits[logits < v[:, [-1]]] = -float("inf")

        probs = torch.softmax(logits, dim=-1)
        next_id = torch.multinomial(probs, num_samples=1)
        out = torch.cat([out, next_id], dim=1)

        if STOP_AT_EOT and next_id.item() == eot_id:
            break

    text = tok.decode(out[0].tolist())
    sample_path = SAMPLE_DIR / f"sample_step_{step:07d}.abc"
    sample_path.write_text(text, encoding="utf-8", newline="\n")
    print(f"[SAMPLE] wrote {sample_path}")
    model.train()

def main():
    set_seed(SEED)
    torch.set_float32_matmul_precision("high")

    
    for p in [TOK_JSON, TRAIN_BIN, VAL_BIN]:
        if not p.exists():
            raise FileNotFoundError(f"Missing: {p}")

    tok = Tokenizer.from_file(str(TOK_JSON))
    print("EOT id:", tok.token_to_id(DELIM))

    train_ds = BinDataset(TRAIN_BIN)
    val_ds = BinDataset(VAL_BIN)
    print("train tokens:", train_ds.n)
    print("val tokens:", val_ds.n)

    model = GPT(CFG).to(DEVICE)
    n_params = sum(p.numel() for p in model.parameters())
    print(f"Model params: {n_params/1e6:.2f}M")

    optim = AdamW(model.parameters(), lr=LR, betas=BETAS, weight_decay=WEIGHT_DECAY)

    CONFIG_JSON.write_text(json.dumps({
        "run_name": RUN_NAME,
        "device": DEVICE,
        "dtype": str(DTYPE),
        "micro_bsz": MICRO_BSZ,
        "grad_accum": GRAD_ACCUM,
        "block_size": BLOCK_SIZE,
        "max_steps": MAX_STEPS,
        "lr": LR,
        "min_lr": MIN_LR,
        "warmup_steps": WARMUP_STEPS,
        "weight_decay": WEIGHT_DECAY,
        "betas": BETAS,
        "grad_clip": GRAD_CLIP,
        "eval_interval": EVAL_INTERVAL,
        "eval_iters": EVAL_ITERS,
        "ckpt_interval": CKPT_INTERVAL,
        "sample_interval": SAMPLE_INTERVAL,
        "dataset": {"train_bin": str(TRAIN_BIN), "val_bin": str(VAL_BIN)},
        "model_cfg": asdict(CFG),
    }, indent=2), encoding="utf-8")

    model.train()
    t0 = time.time()
    running_loss = 0.0
    running_count = 0
    best_val = None

    for step in range(MAX_STEPS):
        lr = cosine_lr(step)
        for pg in optim.param_groups:
            pg["lr"] = lr

        optim.zero_grad(set_to_none=True)

        for _ in range(GRAD_ACCUM):
            x, y = train_ds.get_batch(MICRO_BSZ, BLOCK_SIZE, DEVICE)
            with torch.autocast(device_type="cuda", dtype=DTYPE):
                _, loss = model(x, y)
                loss = loss / GRAD_ACCUM
            loss.backward()

            running_loss += loss.item() * GRAD_ACCUM
            running_count += 1

        if GRAD_CLIP is not None:
            torch.nn.utils.clip_grad_norm_(model.parameters(), GRAD_CLIP)

        optim.step()

        if (step + 1) % LOG_INTERVAL == 0:
            dt = time.time() - t0
            avg_loss = running_loss / max(1, running_count)
            tokens_per_step = MICRO_BSZ * GRAD_ACCUM * BLOCK_SIZE
            tok_per_sec = (tokens_per_step * LOG_INTERVAL) / max(1e-9, dt)

            rec = {
                "step": step + 1,
                "train_loss": avg_loss,
                "lr": lr,
                "tokens_per_step": tokens_per_step,
                "tokens_seen": (step + 1) * tokens_per_step,
                "tok_per_sec": tok_per_sec,
            }
            save_jsonl(METRICS_JSONL, rec)
            print(f"[LOG] step {step+1} | train_loss {avg_loss:.4f} | lr {lr:.2e} | tok/s {tok_per_sec:,.0f}")

            running_loss = 0.0
            running_count = 0
            t0 = time.time()

        if (step + 1) % EVAL_INTERVAL == 0:
            val_loss = estimate_loss(model, val_ds)
            save_jsonl(METRICS_JSONL, {"step": step + 1, "val_loss": val_loss})
            print(f"[EVAL] step {step+1} | val_loss {val_loss:.4f}")
            if best_val is None or val_loss < best_val:
                best_val = val_loss
                save_checkpoint(model, optim, step + 1, best_val)

        if (step + 1) % CKPT_INTERVAL == 0:
            save_checkpoint(model, optim, step + 1, best_val)

        if (step + 1) % SAMPLE_INTERVAL == 0:
            generate_sample(model, tok, val_ds, step + 1)

    save_checkpoint(model, optim, MAX_STEPS, best_val)
    print("[DONE]")

if __name__ == "__main__":
    main()
# Out:
# Writing /content/train_v3_drive.py

# %%
# !python /content/train_v3_drive.py
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/__init__.py:1617: UserWarning: Please use the new API settings to control TF32 behavior, such as torch.backends.cudnn.conv.fp32_precision = 'tf32' or torch.backends.cuda.matmul.fp32_precision = 'ieee'. Old settings, e.g, torch.backends.cuda.matmul.allow_tf32 = True, torch.backends.cudnn.allow_tf32 = True, allowTF32CuDNN() and allowTF32CuBLAS() will be deprecated after Pytorch 2.9. Please see https://pytorch.org/docs/main/notes/cuda.html#tensorfloat-32-tf32-on-ampere-and-later-devices (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:80.)
#   _C._set_float32_matmul_precision(precision)
# EOT id: 1
# train tokens: 136393191
# val tokens: 1277450
# Model initialized: 206.64M parameters
# Model params: 206.64M
# [LOG] step 20 | train_loss 6.2284 | lr 3.00e-05 | tok/s 23,392
# [LOG] step 40 | train_loss 4.1622 | lr 6.00e-05 | tok/s 35,159
# [LOG] step 60 | train_loss 3.0290 | lr 9.00e-05 | tok/s 35,653
# [LOG] step 80 | train_loss 2.5450 | lr 1.20e-04 | tok/s 35,653
# [LOG] step 100 | train_loss 2.3597 | lr 1.50e-04 | tok/s 35,650
# [LOG] step 120 | train_loss 2.2602 | lr 1.80e-04 | tok/s 35,639
# [LOG] step 140 | train_loss 2.1835 | lr 2.10e-04 | tok/s 35,640
# [LOG] step 160 | train_loss 2.1404 | lr 2.40e-04 | tok/s 35,636
# [LOG] step 180 | train_loss 2.1079 | lr 2.70e-04 | tok/s 35,640
# [LOG] step 200 | train_loss 2.0693 | lr 3.00e-04 | tok/s 35,644
# [EVAL] step 200 | val_loss 1.9957
# [CKPT] saved /content/drive/MyDrive/MusicScalingProject/runs/V3_best_150M/checkpoints/ckpt_step_0000200.pt
# [LOG] step 220 | train_loss 1.9979 | lr 3.00e-04 | tok/s 17,088
# [LOG] step 240 | train_loss 1.9383 | lr 3.00e-04 | tok/s 35,659
# [LOG] step 260 | train_loss 1.8851 | lr 3.00e-04 | tok/s 35,647
# Traceback (most recent call last):
#   File "/content/train_v3_drive.py", line 282, in <module>
#     main()
#   File "/content/train_v3_drive.py", line 235, in main
#     running_loss += loss.item() * GRAD_ACCUM
#                     ^^^^^^^^^^^
# KeyboardInterrupt

# %%
import os, shutil

LOCAL_DATA = "/content/dataV3"
os.makedirs(LOCAL_DATA, exist_ok=True)

SRC_DATA = "/content/drive/MyDrive/MusicScalingProject/data/v3"

for fn in ["train.bin", "val.bin", "test.bin", "tokenizer_bpe_4096.json"]:
    shutil.copyfile(f"{SRC_DATA}/{fn}", f"{LOCAL_DATA}/{fn}")

print("Local data files:", os.listdir(LOCAL_DATA))
# Out:
# Local data files: ['tokenizer_bpe_4096.json', 'val.bin', 'train.bin', 'test.bin']

# %%
# %%writefile /content/train_v3_resume.py
from __future__ import annotations

import time, math, json, random
from dataclasses import dataclass, asdict
from pathlib import Path

import numpy as np
import torch
import torch.nn as nn
from torch.optim import AdamW
from tokenizers import Tokenizer

from model import GPT




PROJECT_DIR = Path("/content/drive/MyDrive/MusicScalingProject")
RUN_NAME = "V3_best_150M"
DATA_DIR = Path("/content/dataV3")  

MAX_STEPS = 11000                  


EVAL_ITERS = 50
LOG_INTERVAL = 20
EVAL_INTERVAL = 300                


SAVE_FULL_EVERY = 1500             
KEEP_LAST_FULL = 2                 


SAMPLE_INTERVAL = 1500             


MICRO_BSZ = 16
GRAD_ACCUM = 4
LR = 3e-4
MIN_LR = 3e-5
WARMUP_STEPS = 200
WEIGHT_DECAY = 0.1
BETAS = (0.9, 0.95)
GRAD_CLIP = 1.0

SEED = 1337
DELIM = "<|endoftext|>"

GEN_PROMPT_TOKENS = 256
GEN_NEW_TOKENS = 1024
TEMPERATURE = 1.0
TOP_K = 200
STOP_AT_EOT = True


RUN_DIR = PROJECT_DIR / "runs" / RUN_NAME
CKPT_DIR = RUN_DIR / "checkpoints"
SAMPLE_DIR = RUN_DIR / "samples"
RUN_DIR.mkdir(parents=True, exist_ok=True)
CKPT_DIR.mkdir(parents=True, exist_ok=True)
SAMPLE_DIR.mkdir(parents=True, exist_ok=True)

METRICS_JSONL = RUN_DIR / "metrics.jsonl"
CONFIG_JSON   = RUN_DIR / "run_config.json"

TOK_JSON = DATA_DIR / "tokenizer_bpe_4096.json"
TRAIN_BIN = DATA_DIR / "train.bin"
VAL_BIN   = DATA_DIR / "val.bin"


@dataclass
class ModelConfig:
    n_layer: int = 16
    n_head: int = 16
    n_embd: int = 1024
    block_size: int = 1024
    vocab_size: int = 4096
    dropout: float = 0.1

CFG = ModelConfig()
BLOCK_SIZE = CFG.block_size

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
DTYPE = torch.bfloat16

def set_seed(seed: int):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

def cosine_lr(step: int) -> float:
    if step < WARMUP_STEPS:
        return LR * (step + 1) / WARMUP_STEPS
    progress = min(1.0, (step - WARMUP_STEPS) / max(1, (MAX_STEPS - WARMUP_STEPS)))
    coeff = 0.5 * (1.0 + math.cos(math.pi * progress))
    return MIN_LR + coeff * (LR - MIN_LR)

class BinDataset:
    def __init__(self, path: Path):
        self.data = np.memmap(path, dtype=np.uint16, mode="r")
        self.n = len(self.data)

    def get_batch(self, batch_size: int, block_size: int, device: str):
        ix = np.random.randint(0, self.n - block_size - 1, size=(batch_size,))
        x = np.stack([self.data[i:i+block_size].astype(np.int64) for i in ix])
        y = np.stack([self.data[i+1:i+1+block_size].astype(np.int64) for i in ix])
        x = torch.from_numpy(x).to(device, non_blocking=True)
        y = torch.from_numpy(y).to(device, non_blocking=True)
        return x, y

@torch.no_grad()
def estimate_loss(model: nn.Module, val_ds: BinDataset) -> float:
    model.eval()
    losses = []
    for _ in range(EVAL_ITERS):
        x, y = val_ds.get_batch(MICRO_BSZ, BLOCK_SIZE, DEVICE)
        with torch.autocast(device_type="cuda", dtype=DTYPE):
            _, loss = model(x, y)
        losses.append(loss.item())
    model.train()
    return float(np.mean(losses))

def save_jsonl(path: Path, record: dict):
    with path.open("a", encoding="utf-8") as f:
        f.write(json.dumps(record) + "\n")

def cleanup_full_checkpoints():
    full_ckpts = sorted(CKPT_DIR.glob("full_step_*.pt"))
    if len(full_ckpts) > KEEP_LAST_FULL:
        for p in full_ckpts[:-KEEP_LAST_FULL]:
            p.unlink(missing_ok=True)

def save_full_checkpoint(model, optim, step: int, best_val):
    path = CKPT_DIR / f"full_step_{step:07d}.pt"
    torch.save({
        "step": step,
        "model": model.state_dict(),
        "optim": optim.state_dict(),
        "cfg": asdict(CFG),
        "best_val": best_val,
    }, path)
    print(f"[CKPT] saved FULL {path}")
    cleanup_full_checkpoints()

def load_latest_checkpoint(model, optim):
    
    full_ckpts = sorted(CKPT_DIR.glob("full_step_*.pt"))
    if full_ckpts:
        path = full_ckpts[-1]
        ckpt = torch.load(path, map_location="cpu")
        model.load_state_dict(ckpt["model"])
        optim.load_state_dict(ckpt["optim"])
        step0 = int(ckpt["step"])
        best_val = ckpt.get("best_val", None)
        print(f"[RESUME] loaded FULL {path} (step={step0})")
        return step0, best_val

    
    legacy = sorted(CKPT_DIR.glob("ckpt_step_*.pt"))
    if legacy:
        path = legacy[-1]
        ckpt = torch.load(path, map_location="cpu")
        model.load_state_dict(ckpt["model"])
        if "optim" in ckpt:
            optim.load_state_dict(ckpt["optim"])
        step0 = int(ckpt.get("step", 0))
        best_val = ckpt.get("best_val", None)
        print(f"[RESUME] loaded LEGACY {path} (step={step0})")
        return step0, best_val

    return 0, None

@torch.no_grad()
def generate_sample(model: nn.Module, tok: Tokenizer, val_ds: BinDataset, step: int):
    model.eval()
    eot_id = tok.token_to_id(DELIM)
    assert eot_id is not None

    start = np.random.randint(0, val_ds.n - (GEN_PROMPT_TOKENS + 1))
    prompt_ids = val_ds.data[start:start+GEN_PROMPT_TOKENS].astype(np.int64).tolist()
    out = torch.tensor([prompt_ids], dtype=torch.long, device=DEVICE)

    for _ in range(GEN_NEW_TOKENS):
        out_cond = out[:, -BLOCK_SIZE:]
        with torch.autocast(device_type="cuda", dtype=DTYPE):
            logits, _ = model(out_cond)
        logits = logits[:, -1, :] / TEMPERATURE

        if TOP_K is not None:
            v, _ = torch.topk(logits, TOP_K)
            logits[logits < v[:, [-1]]] = -float("inf")

        probs = torch.softmax(logits, dim=-1)
        next_id = torch.multinomial(probs, num_samples=1)
        out = torch.cat([out, next_id], dim=1)

        if STOP_AT_EOT and next_id.item() == eot_id:
            break

    text = tok.decode(out[0].tolist())
    sample_path = SAMPLE_DIR / f"sample_step_{step:07d}.abc"
    sample_path.write_text(text, encoding="utf-8", newline="\n")
    print(f"[SAMPLE] wrote {sample_path}")
    model.train()

def main():
    set_seed(SEED)
    torch.set_float32_matmul_precision("high")

    for p in [TOK_JSON, TRAIN_BIN, VAL_BIN]:
        if not p.exists():
            raise FileNotFoundError(f"Missing: {p}")

    tok = Tokenizer.from_file(str(TOK_JSON))
    print("EOT id:", tok.token_to_id(DELIM))

    train_ds = BinDataset(TRAIN_BIN)
    val_ds = BinDataset(VAL_BIN)
    print("train tokens:", train_ds.n)
    print("val tokens:", val_ds.n)

    model = GPT(CFG).to(DEVICE)
    n_params = sum(p.numel() for p in model.parameters())
    print(f"Model params: {n_params/1e6:.2f}M")

    optim = AdamW(model.parameters(), lr=LR, betas=BETAS, weight_decay=WEIGHT_DECAY)

    
    if not CONFIG_JSON.exists():
        CONFIG_JSON.write_text(json.dumps({
            "run_name": RUN_NAME,
            "device": DEVICE,
            "dtype": str(DTYPE),
            "micro_bsz": MICRO_BSZ,
            "grad_accum": GRAD_ACCUM,
            "block_size": BLOCK_SIZE,
            "max_steps": MAX_STEPS,
            "lr": LR,
            "min_lr": MIN_LR,
            "warmup_steps": WARMUP_STEPS,
            "weight_decay": WEIGHT_DECAY,
            "betas": BETAS,
            "grad_clip": GRAD_CLIP,
            "eval_interval": EVAL_INTERVAL,
            "eval_iters": EVAL_ITERS,
            "save_full_every": SAVE_FULL_EVERY,
            "keep_last_full": KEEP_LAST_FULL,
            "sample_interval": SAMPLE_INTERVAL,
            "dataset": {"train_bin": str(TRAIN_BIN), "val_bin": str(VAL_BIN)},
            "model_cfg": asdict(CFG),
        }, indent=2), encoding="utf-8")

    step0, best_val = load_latest_checkpoint(model, optim)

    model.train()
    t0 = time.time()
    running_loss = 0.0
    running_count = 0

    for step in range(step0, MAX_STEPS):
        lr = cosine_lr(step)
        for pg in optim.param_groups:
            pg["lr"] = lr

        optim.zero_grad(set_to_none=True)

        for _ in range(GRAD_ACCUM):
            x, y = train_ds.get_batch(MICRO_BSZ, BLOCK_SIZE, DEVICE)
            with torch.autocast(device_type="cuda", dtype=DTYPE):
                _, loss = model(x, y)
                loss = loss / GRAD_ACCUM
            loss.backward()
            running_loss += loss.item() * GRAD_ACCUM
            running_count += 1

        if GRAD_CLIP is not None:
            torch.nn.utils.clip_grad_norm_(model.parameters(), GRAD_CLIP)

        optim.step()

        if (step + 1) % LOG_INTERVAL == 0:
            dt = time.time() - t0
            avg_loss = running_loss / max(1, running_count)
            tokens_per_step = MICRO_BSZ * GRAD_ACCUM * BLOCK_SIZE
            tok_per_sec = (tokens_per_step * LOG_INTERVAL) / max(1e-9, dt)

            save_jsonl(METRICS_JSONL, {
                "step": step + 1,
                "train_loss": avg_loss,
                "lr": lr,
                "tokens_per_step": tokens_per_step,
                "tokens_seen": (step + 1) * tokens_per_step,
                "tok_per_sec": tok_per_sec,
            })
            print(f"[LOG] step {step+1} | train_loss {avg_loss:.4f} | lr {lr:.2e} | tok/s {tok_per_sec:,.0f}")

            running_loss = 0.0
            running_count = 0
            t0 = time.time()

        if (step + 1) % EVAL_INTERVAL == 0:
            val_loss = estimate_loss(model, val_ds)
            save_jsonl(METRICS_JSONL, {"step": step + 1, "val_loss": val_loss})
            print(f"[EVAL] step {step+1} | val_loss {val_loss:.4f}")

            
            if best_val is None or val_loss < best_val:
                best_val = val_loss
                save_full_checkpoint(model, optim, step + 1, best_val)

        
        if (step + 1) % SAVE_FULL_EVERY == 0:
            save_full_checkpoint(model, optim, step + 1, best_val)

        if (step + 1) % SAMPLE_INTERVAL == 0:
            generate_sample(model, tok, val_ds, step + 1)

    save_full_checkpoint(model, optim, MAX_STEPS, best_val)
    print("[DONE]")

if __name__ == "__main__":
    main()
# Out:
# Overwriting /content/train_v3_resume.py

# %%
# !python /content/train_v3_resume.py
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/__init__.py:1617: UserWarning: Please use the new API settings to control TF32 behavior, such as torch.backends.cudnn.conv.fp32_precision = 'tf32' or torch.backends.cuda.matmul.fp32_precision = 'ieee'. Old settings, e.g, torch.backends.cuda.matmul.allow_tf32 = True, torch.backends.cudnn.allow_tf32 = True, allowTF32CuDNN() and allowTF32CuBLAS() will be deprecated after Pytorch 2.9. Please see https://pytorch.org/docs/main/notes/cuda.html#tensorfloat-32-tf32-on-ampere-and-later-devices (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:80.)
#   _C._set_float32_matmul_precision(precision)
# EOT id: 1
# train tokens: 136393191
# val tokens: 1277450
# Model initialized: 206.64M parameters
# Model params: 206.64M
# [RESUME] loaded FULL /content/drive/MyDrive/MusicScalingProject/runs/V3_best_150M/checkpoints/full_step_0001200.pt (step=1200)
# [LOG] step 1220 | train_loss 0.9596 | lr 2.94e-04 | tok/s 35,165
# [LOG] step 1240 | train_loss 0.9663 | lr 2.94e-04 | tok/s 35,681
# [LOG] step 1260 | train_loss 0.9632 | lr 2.94e-04 | tok/s 35,663
# [LOG] step 1280 | train_loss 0.9601 | lr 2.93e-04 | tok/s 35,662
# [LOG] step 1300 | train_loss 0.9545 | lr 2.93e-04 | tok/s 35,658
# [LOG] step 1320 | train_loss 0.9536 | lr 2.93e-04 | tok/s 35,659
# [LOG] step 1340 | train_loss 0.9372 | lr 2.93e-04 | tok/s 35,656
# [LOG] step 1360 | train_loss 0.9343 | lr 2.92e-04 | tok/s 35,641
# [LOG] step 1380 | train_loss 0.9483 | lr 2.92e-04 | tok/s 35,642
# [LOG] step 1400 | train_loss 0.9283 | lr 2.92e-04 | tok/s 35,639
# [LOG] step 1420 | train_loss 0.9401 | lr 2.92e-04 | tok/s 35,640
# [LOG] step 1440 | train_loss 0.9331 | lr 2.91e-04 | tok/s 35,637
# [LOG] step 1460 | train_loss 0.9203 | lr 2.91e-04 | tok/s 35,634
# [LOG] step 1480 | train_loss 0.9197 | lr 2.91e-04 | tok/s 35,638
# [LOG] step 1500 | train_loss 0.9131 | lr 2.90e-04 | tok/s 35,636
# [EVAL] step 1500 | val_loss 0.8751
# [CKPT] saved FULL /content/drive/MyDrive/MusicScalingProject/runs/V3_best_150M/checkpoints/full_step_0001500.pt
# [CKPT] saved FULL /content/drive/MyDrive/MusicScalingProject/runs/V3_best_150M/checkpoints/full_step_0001500.pt
# [SAMPLE] wrote /content/drive/MyDrive/MusicScalingProject/runs/V3_best_150M/samples/sample_step_0001500.abc
# [LOG] step 1520 | train_loss 0.9161 | lr 2.90e-04 | tok/s 17,591
# [LOG] step 1540 | train_loss 0.9142 | lr 2.90e-04 | tok/s 35,647
# [LOG] step 1560 | train_loss 0.9023 | lr 2.90e-04 | tok/s 35,651
# [LOG] step 1580 | train_loss 0.9101 | lr 2.89e-04 | tok/s 35,646
# [LOG] step 1600 | train_loss 0.8997 | lr 2.89e-04 | tok/s 35,645
# [LOG] step 1620 | train_loss 0.9097 | lr 2.89e-04 | tok/s 35,645
# [LOG] step 1640 | train_loss 0.9049 | lr 2.88e-04 | tok/s 35,644
# [LOG] step 1660 | train_loss 0.8999 | lr 2.88e-04 | tok/s 35,646
# [LOG] step 1680 | train_loss 0.8881 | lr 2.88e-04 | tok/s 35,642
# [LOG] step 1700 | train_loss 0.8780 | lr 2.87e-04 | tok/s 35,645
# [LOG] step 1720 | train_loss 0.8868 | lr 2.87e-04 | tok/s 35,644
# [LOG] step 1740 | train_loss 0.8803 | lr 2.87e-04 | tok/s 35,640
# [LOG] step 1760 | train_loss 0.8752 | lr 2.86e-04 | tok/s 35,643
# [LOG] step 1780 | train_loss 0.8771 | lr 2.86e-04 | tok/s 35,645
# [LOG] step 1800 | train_loss 0.8794 | lr 2.86e-04 | tok/s 35,642
# [EVAL] step 1800 | val_loss 0.8330
# [CKPT] saved FULL /content/drive/MyDrive/MusicScalingProject/runs/V3_best_150M/checkpoints/full_step_0001800.pt
# [LOG] step 1820 | train_loss 0.8641 | lr 2.85e-04 | tok/s 26,019
# [LOG] step 1840 | train_loss 0.8629 | lr 2.85e-04 | tok/s 35,631
# [LOG] step 1860 | train_loss 0.8678 | lr 2.85e-04 | tok/s 35,639
# [LOG] step 1880 | train_loss 0.8654 | lr 2.84e-04 | tok/s 35,636
# [LOG] step 1900 | train_loss 0.8690 | lr 2.84e-04 | tok/s 35,633
# [LOG] step 1920 | train_loss 0.8605 | lr 2.83e-04 | tok/s 35,635
# [LOG] step 1940 | train_loss 0.8497 | lr 2.83e-04 | tok/s 35,635
# [LOG] step 1960 | train_loss 0.8475 | lr 2.83e-04 | tok/s 35,637
# [LOG] step 1980 | train_loss 0.8653 | lr 2.82e-04 | tok/s 35,638
# [LOG] step 2000 | train_loss 0.8452 | lr 2.82e-04 | tok/s 35,639
# [LOG] step 2020 | train_loss 0.8574 | lr 2.82e-04 | tok/s 35,639
# [LOG] step 2040 | train_loss 0.8573 | lr 2.81e-04 | tok/s 35,638
# [LOG] step 2060 | train_loss 0.8525 | lr 2.81e-04 | tok/s 35,635
# [LOG] step 2080 | train_loss 0.8553 | lr 2.80e-04 | tok/s 35,638
# [LOG] step 2100 | train_loss 0.8448 | lr 2.80e-04 | tok/s 35,637
# [EVAL] step 2100 | val_loss 0.8151
# [CKPT] saved FULL /content/drive/MyDrive/MusicScalingProject/runs/V3_best_150M/checkpoints/full_step_0002100.pt
# [LOG] step 2120 | train_loss 0.8482 | lr 2.80e-04 | tok/s 26,151
# [LOG] step 2140 | train_loss 0.8545 | lr 2.79e-04 | tok/s 35,626
# [LOG] step 2160 | train_loss 0.8495 | lr 2.79e-04 | tok/s 35,633
# [LOG] step 2180 | train_loss 0.8450 | lr 2.78e-04 | tok/s 35,635
# [LOG] step 2200 | train_loss 0.8349 | lr 2.78e-04 | tok/s 35,623
# [LOG] step 2220 | train_loss 0.8444 | lr 2.77e-04 | tok/s 35,625
# [LOG] step 2240 | train_loss 0.8390 | lr 2.77e-04 | tok/s 35,634
# [LOG] step 2260 | train_loss 0.8417 | lr 2.77e-04 | tok/s 35,632
# [LOG] step 2280 | train_loss 0.8279 | lr 2.76e-04 | tok/s 35,635
# [LOG] step 2300 | train_loss 0.8320 | lr 2.76e-04 | tok/s 35,632
# [LOG] step 2320 | train_loss 0.8450 | lr 2.75e-04 | tok/s 35,635
# [LOG] step 2340 | train_loss 0.8288 | lr 2.75e-04 | tok/s 35,634
# [LOG] step 2360 | train_loss 0.8209 | lr 2.74e-04 | tok/s 35,635
# [LOG] step 2380 | train_loss 0.8221 | lr 2.74e-04 | tok/s 35,638
# [LOG] step 2400 | train_loss 0.8143 | lr 2.73e-04 | tok/s 35,637
# [EVAL] step 2400 | val_loss 0.7960
# [CKPT] saved FULL /content/drive/MyDrive/MusicScalingProject/runs/V3_best_150M/checkpoints/full_step_0002400.pt
# [LOG] step 2420 | train_loss 0.8156 | lr 2.73e-04 | tok/s 26,506
# [LOG] step 2440 | train_loss 0.8130 | lr 2.72e-04 | tok/s 35,639
# [LOG] step 2460 | train_loss 0.8174 | lr 2.72e-04 | tok/s 35,634
# [LOG] step 2480 | train_loss 0.8161 | lr 2.71e-04 | tok/s 35,639
# [LOG] step 2500 | train_loss 0.8161 | lr 2.71e-04 | tok/s 35,638
# [LOG] step 2520 | train_loss 0.8153 | lr 2.70e-04 | tok/s 35,639
# [LOG] step 2540 | train_loss 0.8059 | lr 2.70e-04 | tok/s 35,638
# [LOG] step 2560 | train_loss 0.8095 | lr 2.69e-04 | tok/s 35,638
# [LOG] step 2580 | train_loss 0.8150 | lr 2.69e-04 | tok/s 35,637
# [LOG] step 2600 | train_loss 0.8115 | lr 2.68e-04 | tok/s 35,637
# [LOG] step 2620 | train_loss 0.8141 | lr 2.68e-04 | tok/s 35,634
# [LOG] step 2640 | train_loss 0.8114 | lr 2.67e-04 | tok/s 35,644
# [LOG] step 2660 | train_loss 0.8145 | lr 2.67e-04 | tok/s 35,641
# [LOG] step 2680 | train_loss 0.8046 | lr 2.66e-04 | tok/s 35,631
# [LOG] step 2700 | train_loss 0.8113 | lr 2.66e-04 | tok/s 35,638
# [EVAL] step 2700 | val_loss 0.7760
# [CKPT] saved FULL /content/drive/MyDrive/MusicScalingProject/runs/V3_best_150M/checkpoints/full_step_0002700.pt
# [LOG] step 2720 | train_loss 0.8007 | lr 2.65e-04 | tok/s 26,309
# [LOG] step 2740 | train_loss 0.7982 | lr 2.65e-04 | tok/s 35,638
# [LOG] step 2760 | train_loss 0.8045 | lr 2.64e-04 | tok/s 35,636
# [LOG] step 2780 | train_loss 0.7930 | lr 2.64e-04 | tok/s 35,629
# [LOG] step 2800 | train_loss 0.8026 | lr 2.63e-04 | tok/s 35,629
# [LOG] step 2820 | train_loss 0.7912 | lr 2.63e-04 | tok/s 35,632
# [LOG] step 2840 | train_loss 0.8083 | lr 2.62e-04 | tok/s 35,631
# [LOG] step 2860 | train_loss 0.7986 | lr 2.62e-04 | tok/s 35,636
# [LOG] step 2880 | train_loss 0.7940 | lr 2.61e-04 | tok/s 35,634
# [LOG] step 2900 | train_loss 0.7979 | lr 2.60e-04 | tok/s 35,639
# [LOG] step 2920 | train_loss 0.7953 | lr 2.60e-04 | tok/s 35,644
# [LOG] step 2940 | train_loss 0.7979 | lr 2.59e-04 | tok/s 35,623
# [LOG] step 2960 | train_loss 0.8100 | lr 2.59e-04 | tok/s 35,632
# [LOG] step 2980 | train_loss 0.7935 | lr 2.58e-04 | tok/s 35,642
# [LOG] step 3000 | train_loss 0.7858 | lr 2.58e-04 | tok/s 35,634
# [EVAL] step 3000 | val_loss 0.7804
# [CKPT] saved FULL /content/drive/MyDrive/MusicScalingProject/runs/V3_best_150M/checkpoints/full_step_0003000.pt
# [SAMPLE] wrote /content/drive/MyDrive/MusicScalingProject/runs/V3_best_150M/samples/sample_step_0003000.abc
# [LOG] step 3020 | train_loss 0.7898 | lr 2.57e-04 | tok/s 19,758
# [LOG] step 3040 | train_loss 0.7853 | lr 2.57e-04 | tok/s 35,637
# [LOG] step 3060 | train_loss 0.7850 | lr 2.56e-04 | tok/s 35,642
# [LOG] step 3080 | train_loss 0.7880 | lr 2.55e-04 | tok/s 35,634
# [LOG] step 3100 | train_loss 0.7884 | lr 2.55e-04 | tok/s 35,647
# [LOG] step 3120 | train_loss 0.7847 | lr 2.54e-04 | tok/s 35,643
# [LOG] step 3140 | train_loss 0.7766 | lr 2.54e-04 | tok/s 35,645
# [LOG] step 3160 | train_loss 0.7889 | lr 2.53e-04 | tok/s 35,646
# [LOG] step 3180 | train_loss 0.7872 | lr 2.52e-04 | tok/s 35,641
# [LOG] step 3200 | train_loss 0.7876 | lr 2.52e-04 | tok/s 35,647
# [LOG] step 3220 | train_loss 0.7729 | lr 2.51e-04 | tok/s 35,637
# [LOG] step 3240 | train_loss 0.7733 | lr 2.51e-04 | tok/s 35,644
# [LOG] step 3260 | train_loss 0.7729 | lr 2.50e-04 | tok/s 35,624
# [LOG] step 3280 | train_loss 0.7710 | lr 2.49e-04 | tok/s 35,620
# [LOG] step 3300 | train_loss 0.7848 | lr 2.49e-04 | tok/s 35,630
# [EVAL] step 3300 | val_loss 0.7623
# [CKPT] saved FULL /content/drive/MyDrive/MusicScalingProject/runs/V3_best_150M/checkpoints/full_step_0003300.pt
# [LOG] step 3320 | train_loss 0.7774 | lr 2.48e-04 | tok/s 26,108
# [LOG] step 3340 | train_loss 0.7589 | lr 2.48e-04 | tok/s 35,644
# [LOG] step 3360 | train_loss 0.7785 | lr 2.47e-04 | tok/s 35,635
# [LOG] step 3380 | train_loss 0.7606 | lr 2.46e-04 | tok/s 35,629
# [LOG] step 3400 | train_loss 0.7615 | lr 2.46e-04 | tok/s 35,622
# [LOG] step 3420 | train_loss 0.7739 | lr 2.45e-04 | tok/s 35,631
# [LOG] step 3440 | train_loss 0.7745 | lr 2.44e-04 | tok/s 35,631
# [LOG] step 3460 | train_loss 0.7614 | lr 2.44e-04 | tok/s 35,630
# [LOG] step 3480 | train_loss 0.7641 | lr 2.43e-04 | tok/s 35,632
# [LOG] step 3500 | train_loss 0.7571 | lr 2.42e-04 | tok/s 35,632
# [LOG] step 3520 | train_loss 0.7719 | lr 2.42e-04 | tok/s 35,626
# [LOG] step 3540 | train_loss 0.7650 | lr 2.41e-04 | tok/s 35,629
# [LOG] step 3560 | train_loss 0.7724 | lr 2.41e-04 | tok/s 35,630
# [LOG] step 3580 | train_loss 0.7612 | lr 2.40e-04 | tok/s 35,629
# [LOG] step 3600 | train_loss 0.7583 | lr 2.39e-04 | tok/s 35,632
# [EVAL] step 3600 | val_loss 0.7432
# [CKPT] saved FULL /content/drive/MyDrive/MusicScalingProject/runs/V3_best_150M/checkpoints/full_step_0003600.pt
# [LOG] step 3620 | train_loss 0.7590 | lr 2.39e-04 | tok/s 26,081
# [LOG] step 3640 | train_loss 0.7648 | lr 2.38e-04 | tok/s 35,629
# [LOG] step 3660 | train_loss 0.7523 | lr 2.37e-04 | tok/s 35,624
# [LOG] step 3680 | train_loss 0.7595 | lr 2.37e-04 | tok/s 35,628
# [LOG] step 3700 | train_loss 0.7680 | lr 2.36e-04 | tok/s 35,625
# [LOG] step 3720 | train_loss 0.7537 | lr 2.35e-04 | tok/s 35,624
# [LOG] step 3740 | train_loss 0.7600 | lr 2.35e-04 | tok/s 35,626
# [LOG] step 3760 | train_loss 0.7519 | lr 2.34e-04 | tok/s 35,620
# [LOG] step 3780 | train_loss 0.7540 | lr 2.33e-04 | tok/s 35,621
# [LOG] step 3800 | train_loss 0.7476 | lr 2.33e-04 | tok/s 35,623
# [LOG] step 3820 | train_loss 0.7450 | lr 2.32e-04 | tok/s 35,626
# [LOG] step 3840 | train_loss 0.7483 | lr 2.31e-04 | tok/s 35,630
# [LOG] step 3860 | train_loss 0.7544 | lr 2.30e-04 | tok/s 35,625
# [LOG] step 3880 | train_loss 0.7486 | lr 2.30e-04 | tok/s 35,625
# [LOG] step 3900 | train_loss 0.7446 | lr 2.29e-04 | tok/s 35,629
# [EVAL] step 3900 | val_loss 0.7424
# [CKPT] saved FULL /content/drive/MyDrive/MusicScalingProject/runs/V3_best_150M/checkpoints/full_step_0003900.pt
# [LOG] step 3920 | train_loss 0.7477 | lr 2.28e-04 | tok/s 26,185
# [LOG] step 3940 | train_loss 0.7567 | lr 2.28e-04 | tok/s 35,632
# [LOG] step 3960 | train_loss 0.7541 | lr 2.27e-04 | tok/s 35,647
# [LOG] step 3980 | train_loss 0.7527 | lr 2.26e-04 | tok/s 35,637
# [LOG] step 4000 | train_loss 0.7507 | lr 2.26e-04 | tok/s 35,630
# [LOG] step 4020 | train_loss 0.7364 | lr 2.25e-04 | tok/s 35,632
# [LOG] step 4040 | train_loss 0.7401 | lr 2.24e-04 | tok/s 35,634
# [LOG] step 4060 | train_loss 0.7444 | lr 2.24e-04 | tok/s 35,631
# [LOG] step 4080 | train_loss 0.7542 | lr 2.23e-04 | tok/s 35,635
# [LOG] step 4100 | train_loss 0.7489 | lr 2.22e-04 | tok/s 35,633
# [LOG] step 4120 | train_loss 0.7479 | lr 2.21e-04 | tok/s 35,632
# [LOG] step 4140 | train_loss 0.7514 | lr 2.21e-04 | tok/s 35,632
# [LOG] step 4160 | train_loss 0.7418 | lr 2.20e-04 | tok/s 35,634
# [LOG] step 4180 | train_loss 0.7418 | lr 2.19e-04 | tok/s 35,634
# [LOG] step 4200 | train_loss 0.7501 | lr 2.19e-04 | tok/s 35,632
# [EVAL] step 4200 | val_loss 0.7246
# [CKPT] saved FULL /content/drive/MyDrive/MusicScalingProject/runs/V3_best_150M/checkpoints/full_step_0004200.pt
# [LOG] step 4220 | train_loss 0.7374 | lr 2.18e-04 | tok/s 26,259
# [LOG] step 4240 | train_loss 0.7283 | lr 2.17e-04 | tok/s 35,632
# [LOG] step 4260 | train_loss 0.7341 | lr 2.16e-04 | tok/s 35,633
# [LOG] step 4280 | train_loss 0.7346 | lr 2.16e-04 | tok/s 35,632
# [LOG] step 4300 | train_loss 0.7389 | lr 2.15e-04 | tok/s 35,632
# [LOG] step 4320 | train_loss 0.7239 | lr 2.14e-04 | tok/s 35,633
# [LOG] step 4340 | train_loss 0.7296 | lr 2.13e-04 | tok/s 35,633
# [LOG] step 4360 | train_loss 0.7302 | lr 2.13e-04 | tok/s 35,630
# [LOG] step 4380 | train_loss 0.7449 | lr 2.12e-04 | tok/s 35,630
# [LOG] step 4400 | train_loss 0.7297 | lr 2.11e-04 | tok/s 35,633
# [LOG] step 4420 | train_loss 0.7399 | lr 2.10e-04 | tok/s 35,636
# [LOG] step 4440 | train_loss 0.7409 | lr 2.10e-04 | tok/s 35,631
# [LOG] step 4460 | train_loss 0.7435 | lr 2.09e-04 | tok/s 35,630
# [LOG] step 4480 | train_loss 0.7288 | lr 2.08e-04 | tok/s 35,630
# [LOG] step 4500 | train_loss 0.7308 | lr 2.08e-04 | tok/s 35,637
# [EVAL] step 4500 | val_loss 0.7320
# [CKPT] saved FULL /content/drive/MyDrive/MusicScalingProject/runs/V3_best_150M/checkpoints/full_step_0004500.pt
# [SAMPLE] wrote /content/drive/MyDrive/MusicScalingProject/runs/V3_best_150M/samples/sample_step_0004500.abc
# [LOG] step 4520 | train_loss 0.7399 | lr 2.07e-04 | tok/s 20,410
# [LOG] step 4540 | train_loss 0.7272 | lr 2.06e-04 | tok/s 35,637
# [LOG] step 4560 | train_loss 0.7267 | lr 2.05e-04 | tok/s 35,635
# [LOG] step 4580 | train_loss 0.7224 | lr 2.05e-04 | tok/s 35,639
# [LOG] step 4600 | train_loss 0.7362 | lr 2.04e-04 | tok/s 35,628
# [LOG] step 4620 | train_loss 0.7186 | lr 2.03e-04 | tok/s 35,627
# [LOG] step 4640 | train_loss 0.7198 | lr 2.02e-04 | tok/s 35,626
# [LOG] step 4660 | train_loss 0.7315 | lr 2.01e-04 | tok/s 35,625
# [LOG] step 4680 | train_loss 0.7174 | lr 2.01e-04 | tok/s 35,625
# [LOG] step 4700 | train_loss 0.7320 | lr 2.00e-04 | tok/s 35,624
# [LOG] step 4720 | train_loss 0.7287 | lr 1.99e-04 | tok/s 35,626
# [LOG] step 4740 | train_loss 0.7137 | lr 1.98e-04 | tok/s 35,626
# [LOG] step 4760 | train_loss 0.7194 | lr 1.98e-04 | tok/s 35,624
# [LOG] step 4780 | train_loss 0.7227 | lr 1.97e-04 | tok/s 35,615
# [LOG] step 4800 | train_loss 0.7258 | lr 1.96e-04 | tok/s 35,622
# [EVAL] step 4800 | val_loss 0.7177
# [CKPT] saved FULL /content/drive/MyDrive/MusicScalingProject/runs/V3_best_150M/checkpoints/full_step_0004800.pt
# [LOG] step 4820 | train_loss 0.7191 | lr 1.95e-04 | tok/s 26,070
# [LOG] step 4840 | train_loss 0.7018 | lr 1.95e-04 | tok/s 35,631
# [LOG] step 4860 | train_loss 0.7291 | lr 1.94e-04 | tok/s 35,618
# [LOG] step 4880 | train_loss 0.7216 | lr 1.93e-04 | tok/s 35,627
# [LOG] step 4900 | train_loss 0.7108 | lr 1.92e-04 | tok/s 35,618
# [LOG] step 4920 | train_loss 0.7136 | lr 1.92e-04 | tok/s 35,621
# [LOG] step 4940 | train_loss 0.7223 | lr 1.91e-04 | tok/s 35,618
# [LOG] step 4960 | train_loss 0.7119 | lr 1.90e-04 | tok/s 35,615
# [LOG] step 4980 | train_loss 0.7141 | lr 1.89e-04 | tok/s 35,616
# [LOG] step 5000 | train_loss 0.7196 | lr 1.88e-04 | tok/s 35,617
# [LOG] step 5020 | train_loss 0.7260 | lr 1.88e-04 | tok/s 35,610
# [LOG] step 5040 | train_loss 0.7225 | lr 1.87e-04 | tok/s 35,598
# [LOG] step 5060 | train_loss 0.7268 | lr 1.86e-04 | tok/s 35,595
# [LOG] step 5080 | train_loss 0.7147 | lr 1.85e-04 | tok/s 35,594
# [LOG] step 5100 | train_loss 0.7091 | lr 1.85e-04 | tok/s 35,598
# [EVAL] step 5100 | val_loss 0.7010
# [CKPT] saved FULL /content/drive/MyDrive/MusicScalingProject/runs/V3_best_150M/checkpoints/full_step_0005100.pt
# [LOG] step 5120 | train_loss 0.7076 | lr 1.84e-04 | tok/s 25,875
# [LOG] step 5140 | train_loss 0.7146 | lr 1.83e-04 | tok/s 35,603
# [LOG] step 5160 | train_loss 0.7155 | lr 1.82e-04 | tok/s 35,604
# [LOG] step 5180 | train_loss 0.7057 | lr 1.81e-04 | tok/s 35,606
# [LOG] step 5200 | train_loss 0.7205 | lr 1.81e-04 | tok/s 35,602
# [LOG] step 5220 | train_loss 0.7036 | lr 1.80e-04 | tok/s 35,605
# [LOG] step 5240 | train_loss 0.7082 | lr 1.79e-04 | tok/s 35,603
# [LOG] step 5260 | train_loss 0.7035 | lr 1.78e-04 | tok/s 35,602
# [LOG] step 5280 | train_loss 0.7078 | lr 1.78e-04 | tok/s 35,605
# [LOG] step 5300 | train_loss 0.7057 | lr 1.77e-04 | tok/s 35,601
# [LOG] step 5320 | train_loss 0.7037 | lr 1.76e-04 | tok/s 35,602
# [LOG] step 5340 | train_loss 0.7033 | lr 1.75e-04 | tok/s 35,599
# [LOG] step 5360 | train_loss 0.7189 | lr 1.74e-04 | tok/s 35,603
# [LOG] step 5380 | train_loss 0.7107 | lr 1.74e-04 | tok/s 35,601
# [LOG] step 5400 | train_loss 0.7034 | lr 1.73e-04 | tok/s 35,600
# [EVAL] step 5400 | val_loss 0.7187
# [LOG] step 5420 | train_loss 0.7033 | lr 1.72e-04 | tok/s 29,233
# [LOG] step 5440 | train_loss 0.7029 | lr 1.71e-04 | tok/s 35,604
# [LOG] step 5460 | train_loss 0.7137 | lr 1.71e-04 | tok/s 35,601
# [LOG] step 5480 | train_loss 0.6979 | lr 1.70e-04 | tok/s 35,603
# [LOG] step 5500 | train_loss 0.7141 | lr 1.69e-04 | tok/s 35,602
# [LOG] step 5520 | train_loss 0.7140 | lr 1.68e-04 | tok/s 35,603
# [LOG] step 5540 | train_loss 0.6969 | lr 1.67e-04 | tok/s 35,604
# [LOG] step 5560 | train_loss 0.7018 | lr 1.67e-04 | tok/s 35,604
# [LOG] step 5580 | train_loss 0.7099 | lr 1.66e-04 | tok/s 35,608
# [LOG] step 5600 | train_loss 0.6995 | lr 1.65e-04 | tok/s 35,607
# [LOG] step 5620 | train_loss 0.7028 | lr 1.64e-04 | tok/s 35,605
# [LOG] step 5640 | train_loss 0.6957 | lr 1.63e-04 | tok/s 35,603
# [LOG] step 5660 | train_loss 0.6982 | lr 1.63e-04 | tok/s 35,604
# [LOG] step 5680 | train_loss 0.7005 | lr 1.62e-04 | tok/s 35,606
# [LOG] step 5700 | train_loss 0.6872 | lr 1.61e-04 | tok/s 35,603
# [EVAL] step 5700 | val_loss 0.6875
# [CKPT] saved FULL /content/drive/MyDrive/MusicScalingProject/runs/V3_best_150M/checkpoints/full_step_0005700.pt
# [LOG] step 5720 | train_loss 0.6790 | lr 1.60e-04 | tok/s 26,145
# [LOG] step 5740 | train_loss 0.7045 | lr 1.60e-04 | tok/s 35,616
# [LOG] step 5760 | train_loss 0.7084 | lr 1.59e-04 | tok/s 35,605
# [LOG] step 5780 | train_loss 0.6949 | lr 1.58e-04 | tok/s 35,601
# [LOG] step 5800 | train_loss 0.7015 | lr 1.57e-04 | tok/s 35,603
# [LOG] step 5820 | train_loss 0.6939 | lr 1.56e-04 | tok/s 35,599
# [LOG] step 5840 | train_loss 0.6936 | lr 1.56e-04 | tok/s 35,599
# [LOG] step 5860 | train_loss 0.6896 | lr 1.55e-04 | tok/s 35,600
# [LOG] step 5880 | train_loss 0.7077 | lr 1.54e-04 | tok/s 35,597
# [LOG] step 5900 | train_loss 0.6847 | lr 1.53e-04 | tok/s 35,598
# [LOG] step 5920 | train_loss 0.6888 | lr 1.52e-04 | tok/s 35,599
# [LOG] step 5940 | train_loss 0.6980 | lr 1.52e-04 | tok/s 35,598
# [LOG] step 5960 | train_loss 0.6857 | lr 1.51e-04 | tok/s 35,597
# [LOG] step 5980 | train_loss 0.6939 | lr 1.50e-04 | tok/s 35,597
# [LOG] step 6000 | train_loss 0.6812 | lr 1.49e-04 | tok/s 35,595
# [EVAL] step 6000 | val_loss 0.6948
# [CKPT] saved FULL /content/drive/MyDrive/MusicScalingProject/runs/V3_best_150M/checkpoints/full_step_0006000.pt
# [SAMPLE] wrote /content/drive/MyDrive/MusicScalingProject/runs/V3_best_150M/samples/sample_step_0006000.abc
# [LOG] step 6020 | train_loss 0.6852 | lr 1.49e-04 | tok/s 20,325
# [LOG] step 6040 | train_loss 0.6897 | lr 1.48e-04 | tok/s 35,603
# [LOG] step 6060 | train_loss 0.6890 | lr 1.47e-04 | tok/s 35,602
# [LOG] step 6080 | train_loss 0.6893 | lr 1.46e-04 | tok/s 35,598
# [LOG] step 6100 | train_loss 0.6948 | lr 1.45e-04 | tok/s 35,597
# [LOG] step 6120 | train_loss 0.6837 | lr 1.45e-04 | tok/s 35,594
# [LOG] step 6140 | train_loss 0.6854 | lr 1.44e-04 | tok/s 35,599
# [LOG] step 6160 | train_loss 0.6993 | lr 1.43e-04 | tok/s 35,597
# [LOG] step 6180 | train_loss 0.6860 | lr 1.42e-04 | tok/s 35,598
# [LOG] step 6200 | train_loss 0.6880 | lr 1.42e-04 | tok/s 35,600
# [LOG] step 6220 | train_loss 0.6852 | lr 1.41e-04 | tok/s 35,596
# [LOG] step 6240 | train_loss 0.6944 | lr 1.40e-04 | tok/s 35,599
# [LOG] step 6260 | train_loss 0.6731 | lr 1.39e-04 | tok/s 35,598
# [LOG] step 6280 | train_loss 0.6770 | lr 1.39e-04 | tok/s 35,595
# [LOG] step 6300 | train_loss 0.6806 | lr 1.38e-04 | tok/s 35,597
# [EVAL] step 6300 | val_loss 0.6768
# [CKPT] saved FULL /content/drive/MyDrive/MusicScalingProject/runs/V3_best_150M/checkpoints/full_step_0006300.pt
# [LOG] step 6320 | train_loss 0.6791 | lr 1.37e-04 | tok/s 25,985
# [LOG] step 6340 | train_loss 0.6774 | lr 1.36e-04 | tok/s 35,609
# [LOG] step 6360 | train_loss 0.6623 | lr 1.35e-04 | tok/s 35,609
# [LOG] step 6380 | train_loss 0.6805 | lr 1.35e-04 | tok/s 35,602
# [LOG] step 6400 | train_loss 0.6785 | lr 1.34e-04 | tok/s 35,608
# [LOG] step 6420 | train_loss 0.6737 | lr 1.33e-04 | tok/s 35,595
# [LOG] step 6440 | train_loss 0.6814 | lr 1.32e-04 | tok/s 35,609
# [LOG] step 6460 | train_loss 0.6750 | lr 1.32e-04 | tok/s 35,598
# [LOG] step 6480 | train_loss 0.6716 | lr 1.31e-04 | tok/s 35,600
# [LOG] step 6500 | train_loss 0.6679 | lr 1.30e-04 | tok/s 35,594
# [LOG] step 6520 | train_loss 0.6908 | lr 1.29e-04 | tok/s 35,612
# [LOG] step 6540 | train_loss 0.6802 | lr 1.29e-04 | tok/s 35,596
# [LOG] step 6560 | train_loss 0.6715 | lr 1.28e-04 | tok/s 35,598
# [LOG] step 6580 | train_loss 0.6756 | lr 1.27e-04 | tok/s 35,594
# [LOG] step 6600 | train_loss 0.6704 | lr 1.26e-04 | tok/s 35,599
# [EVAL] step 6600 | val_loss 0.6879
# [LOG] step 6620 | train_loss 0.6773 | lr 1.26e-04 | tok/s 28,076
# [LOG] step 6640 | train_loss 0.6693 | lr 1.25e-04 | tok/s 35,598
# [LOG] step 6660 | train_loss 0.6790 | lr 1.24e-04 | tok/s 35,604
# [LOG] step 6680 | train_loss 0.6766 | lr 1.23e-04 | tok/s 35,611
# [LOG] step 6700 | train_loss 0.6814 | lr 1.23e-04 | tok/s 35,603
# [LOG] step 6720 | train_loss 0.6753 | lr 1.22e-04 | tok/s 35,606
# [LOG] step 6740 | train_loss 0.6683 | lr 1.21e-04 | tok/s 35,607
# [LOG] step 6760 | train_loss 0.6726 | lr 1.20e-04 | tok/s 35,596
# [LOG] step 6780 | train_loss 0.6752 | lr 1.20e-04 | tok/s 35,610
# [LOG] step 6800 | train_loss 0.6691 | lr 1.19e-04 | tok/s 35,606
# [LOG] step 6820 | train_loss 0.6696 | lr 1.18e-04 | tok/s 35,607
# [LOG] step 6840 | train_loss 0.6694 | lr 1.17e-04 | tok/s 35,599
# [LOG] step 6860 | train_loss 0.6637 | lr 1.17e-04 | tok/s 35,602
# [LOG] step 6880 | train_loss 0.6587 | lr 1.16e-04 | tok/s 35,595
# [LOG] step 6900 | train_loss 0.6671 | lr 1.15e-04 | tok/s 35,591
# [EVAL] step 6900 | val_loss 0.6842
# [LOG] step 6920 | train_loss 0.6723 | lr 1.14e-04 | tok/s 29,235
# [LOG] step 6940 | train_loss 0.6701 | lr 1.14e-04 | tok/s 35,598
# [LOG] step 6960 | train_loss 0.6594 | lr 1.13e-04 | tok/s 35,602
# [LOG] step 6980 | train_loss 0.6589 | lr 1.12e-04 | tok/s 35,601
# [LOG] step 7000 | train_loss 0.6697 | lr 1.12e-04 | tok/s 35,598
# [LOG] step 7020 | train_loss 0.6657 | lr 1.11e-04 | tok/s 35,599
# [LOG] step 7040 | train_loss 0.6643 | lr 1.10e-04 | tok/s 35,599
# [LOG] step 7060 | train_loss 0.6691 | lr 1.09e-04 | tok/s 35,597
# [LOG] step 7080 | train_loss 0.6639 | lr 1.09e-04 | tok/s 35,599
# [LOG] step 7100 | train_loss 0.6561 | lr 1.08e-04 | tok/s 35,601
# [LOG] step 7120 | train_loss 0.6563 | lr 1.07e-04 | tok/s 35,600
# [LOG] step 7140 | train_loss 0.6571 | lr 1.07e-04 | tok/s 35,601
# [LOG] step 7160 | train_loss 0.6619 | lr 1.06e-04 | tok/s 35,597
# [LOG] step 7180 | train_loss 0.6655 | lr 1.05e-04 | tok/s 35,601
# [LOG] step 7200 | train_loss 0.6627 | lr 1.04e-04 | tok/s 35,599
# [EVAL] step 7200 | val_loss 0.6761
# [CKPT] saved FULL /content/drive/MyDrive/MusicScalingProject/runs/V3_best_150M/checkpoints/full_step_0007200.pt
# [LOG] step 7220 | train_loss 0.6668 | lr 1.04e-04 | tok/s 22,983
# [LOG] step 7240 | train_loss 0.6517 | lr 1.03e-04 | tok/s 35,622
# [LOG] step 7260 | train_loss 0.6691 | lr 1.02e-04 | tok/s 35,610
# [LOG] step 7280 | train_loss 0.6511 | lr 1.02e-04 | tok/s 35,628
# [LOG] step 7300 | train_loss 0.6641 | lr 1.01e-04 | tok/s 35,623
# [LOG] step 7320 | train_loss 0.6621 | lr 1.00e-04 | tok/s 35,615
# [LOG] step 7340 | train_loss 0.6543 | lr 9.96e-05 | tok/s 35,628
# [LOG] step 7360 | train_loss 0.6525 | lr 9.89e-05 | tok/s 35,620
# [LOG] step 7380 | train_loss 0.6536 | lr 9.82e-05 | tok/s 35,620
# [LOG] step 7400 | train_loss 0.6554 | lr 9.75e-05 | tok/s 35,613
# [LOG] step 7420 | train_loss 0.6578 | lr 9.69e-05 | tok/s 35,620
# [LOG] step 7440 | train_loss 0.6615 | lr 9.62e-05 | tok/s 35,625
# [LOG] step 7460 | train_loss 0.6513 | lr 9.55e-05 | tok/s 35,626
# [LOG] step 7480 | train_loss 0.6538 | lr 9.48e-05 | tok/s 35,620
# [LOG] step 7500 | train_loss 0.6553 | lr 9.42e-05 | tok/s 35,617
# [EVAL] step 7500 | val_loss 0.6699
# [CKPT] saved FULL /content/drive/MyDrive/MusicScalingProject/runs/V3_best_150M/checkpoints/full_step_0007500.pt
# [CKPT] saved FULL /content/drive/MyDrive/MusicScalingProject/runs/V3_best_150M/checkpoints/full_step_0007500.pt
# [SAMPLE] wrote /content/drive/MyDrive/MusicScalingProject/runs/V3_best_150M/samples/sample_step_0007500.abc
# [LOG] step 7520 | train_loss 0.6588 | lr 9.35e-05 | tok/s 11,397
# [LOG] step 7540 | train_loss 0.6595 | lr 9.28e-05 | tok/s 35,647
# [LOG] step 7560 | train_loss 0.6452 | lr 9.22e-05 | tok/s 35,608
# [LOG] step 7580 | train_loss 0.6553 | lr 9.15e-05 | tok/s 35,611
# [LOG] step 7600 | train_loss 0.6427 | lr 9.08e-05 | tok/s 35,615
# [LOG] step 7620 | train_loss 0.6383 | lr 9.02e-05 | tok/s 35,611
# [LOG] step 7640 | train_loss 0.6494 | lr 8.95e-05 | tok/s 35,614
# [LOG] step 7660 | train_loss 0.6532 | lr 8.89e-05 | tok/s 35,612
# [LOG] step 7680 | train_loss 0.6512 | lr 8.82e-05 | tok/s 35,614
# [LOG] step 7700 | train_loss 0.6452 | lr 8.76e-05 | tok/s 35,614
# [LOG] step 7720 | train_loss 0.6505 | lr 8.70e-05 | tok/s 35,615
# [LOG] step 7740 | train_loss 0.6598 | lr 8.63e-05 | tok/s 35,614
# [LOG] step 7760 | train_loss 0.6472 | lr 8.57e-05 | tok/s 35,612
# [LOG] step 7780 | train_loss 0.6479 | lr 8.50e-05 | tok/s 35,611
# [LOG] step 7800 | train_loss 0.6493 | lr 8.44e-05 | tok/s 35,611
# [EVAL] step 7800 | val_loss 0.6781
# [LOG] step 7820 | train_loss 0.6492 | lr 8.38e-05 | tok/s 29,251
# [LOG] step 7840 | train_loss 0.6419 | lr 8.32e-05 | tok/s 35,609
# [LOG] step 7860 | train_loss 0.6488 | lr 8.25e-05 | tok/s 35,613
# [LOG] step 7880 | train_loss 0.6408 | lr 8.19e-05 | tok/s 35,613
# [LOG] step 7900 | train_loss 0.6408 | lr 8.13e-05 | tok/s 35,612
# [LOG] step 7920 | train_loss 0.6478 | lr 8.07e-05 | tok/s 35,611
# [LOG] step 7940 | train_loss 0.6421 | lr 8.01e-05 | tok/s 35,613
# [LOG] step 7960 | train_loss 0.6400 | lr 7.95e-05 | tok/s 35,610
# [LOG] step 7980 | train_loss 0.6443 | lr 7.89e-05 | tok/s 35,613
# [LOG] step 8000 | train_loss 0.6364 | lr 7.83e-05 | tok/s 35,612
# [LOG] step 8020 | train_loss 0.6378 | lr 7.77e-05 | tok/s 35,614
# [LOG] step 8040 | train_loss 0.6366 | lr 7.71e-05 | tok/s 35,611
# [LOG] step 8060 | train_loss 0.6393 | lr 7.65e-05 | tok/s 35,613
# [LOG] step 8080 | train_loss 0.6491 | lr 7.59e-05 | tok/s 35,616
# [LOG] step 8100 | train_loss 0.6536 | lr 7.53e-05 | tok/s 35,616
# [EVAL] step 8100 | val_loss 0.6786
# [LOG] step 8120 | train_loss 0.6488 | lr 7.47e-05 | tok/s 29,251
# [LOG] step 8140 | train_loss 0.6398 | lr 7.41e-05 | tok/s 35,615
# [LOG] step 8160 | train_loss 0.6520 | lr 7.35e-05 | tok/s 35,618
# [LOG] step 8180 | train_loss 0.6442 | lr 7.30e-05 | tok/s 35,614
# [LOG] step 8200 | train_loss 0.6537 | lr 7.24e-05 | tok/s 35,615
# [LOG] step 8220 | train_loss 0.6317 | lr 7.18e-05 | tok/s 35,618
# [LOG] step 8240 | train_loss 0.6310 | lr 7.12e-05 | tok/s 35,616
# [LOG] step 8260 | train_loss 0.6472 | lr 7.07e-05 | tok/s 35,611
# [LOG] step 8280 | train_loss 0.6497 | lr 7.01e-05 | tok/s 35,616
# [LOG] step 8300 | train_loss 0.6411 | lr 6.96e-05 | tok/s 35,613
# [LOG] step 8320 | train_loss 0.6352 | lr 6.90e-05 | tok/s 35,613
# [LOG] step 8340 | train_loss 0.6466 | lr 6.85e-05 | tok/s 35,614
# [LOG] step 8360 | train_loss 0.6510 | lr 6.79e-05 | tok/s 35,616
# [LOG] step 8380 | train_loss 0.6442 | lr 6.74e-05 | tok/s 35,613
# [LOG] step 8400 | train_loss 0.6375 | lr 6.68e-05 | tok/s 35,614
# [EVAL] step 8400 | val_loss 0.6611
# [CKPT] saved FULL /content/drive/MyDrive/MusicScalingProject/runs/V3_best_150M/checkpoints/full_step_0008400.pt
# [LOG] step 8420 | train_loss 0.6428 | lr 6.63e-05 | tok/s 26,337
# [LOG] step 8440 | train_loss 0.6273 | lr 6.58e-05 | tok/s 35,624
# [LOG] step 8460 | train_loss 0.6525 | lr 6.52e-05 | tok/s 35,629
# [LOG] step 8480 | train_loss 0.6431 | lr 6.47e-05 | tok/s 35,623
# [LOG] step 8500 | train_loss 0.6321 | lr 6.42e-05 | tok/s 35,620
# [LOG] step 8520 | train_loss 0.6312 | lr 6.37e-05 | tok/s 35,616
# [LOG] step 8540 | train_loss 0.6380 | lr 6.31e-05 | tok/s 35,624
# [LOG] step 8560 | train_loss 0.6432 | lr 6.26e-05 | tok/s 35,615
# [LOG] step 8580 | train_loss 0.6292 | lr 6.21e-05 | tok/s 35,617
# [LOG] step 8600 | train_loss 0.6336 | lr 6.16e-05 | tok/s 35,621
# [LOG] step 8620 | train_loss 0.6376 | lr 6.11e-05 | tok/s 35,624
# [LOG] step 8640 | train_loss 0.6300 | lr 6.06e-05 | tok/s 35,624
# [LOG] step 8660 | train_loss 0.6330 | lr 6.01e-05 | tok/s 35,621
# [LOG] step 8680 | train_loss 0.6337 | lr 5.96e-05 | tok/s 35,619
# [LOG] step 8700 | train_loss 0.6351 | lr 5.91e-05 | tok/s 35,620
# [EVAL] step 8700 | val_loss 0.6710
# [LOG] step 8720 | train_loss 0.6318 | lr 5.86e-05 | tok/s 29,252
# [LOG] step 8740 | train_loss 0.6442 | lr 5.82e-05 | tok/s 35,618
# [LOG] step 8760 | train_loss 0.6321 | lr 5.77e-05 | tok/s 35,621
# [LOG] step 8780 | train_loss 0.6288 | lr 5.72e-05 | tok/s 35,624
# [LOG] step 8800 | train_loss 0.6356 | lr 5.67e-05 | tok/s 35,619
# [LOG] step 8820 | train_loss 0.6394 | lr 5.63e-05 | tok/s 35,622
# [LOG] step 8840 | train_loss 0.6393 | lr 5.58e-05 | tok/s 35,619
# [LOG] step 8860 | train_loss 0.6223 | lr 5.53e-05 | tok/s 35,617
# [LOG] step 8880 | train_loss 0.6282 | lr 5.49e-05 | tok/s 35,620
# [LOG] step 8900 | train_loss 0.6426 | lr 5.44e-05 | tok/s 35,619
# [LOG] step 8920 | train_loss 0.6305 | lr 5.40e-05 | tok/s 35,611
# [LOG] step 8940 | train_loss 0.6405 | lr 5.35e-05 | tok/s 35,612
# [LOG] step 8960 | train_loss 0.6343 | lr 5.31e-05 | tok/s 35,609
# [LOG] step 8980 | train_loss 0.6279 | lr 5.27e-05 | tok/s 35,611
# [LOG] step 9000 | train_loss 0.6286 | lr 5.22e-05 | tok/s 35,614
# [EVAL] step 9000 | val_loss 0.6665
# [CKPT] saved FULL /content/drive/MyDrive/MusicScalingProject/runs/V3_best_150M/checkpoints/full_step_0009000.pt
# [SAMPLE] wrote /content/drive/MyDrive/MusicScalingProject/runs/V3_best_150M/samples/sample_step_0009000.abc
# [LOG] step 9020 | train_loss 0.6324 | lr 5.18e-05 | tok/s 23,492
# [LOG] step 9040 | train_loss 0.6407 | lr 5.14e-05 | tok/s 35,618
# [LOG] step 9060 | train_loss 0.6348 | lr 5.10e-05 | tok/s 35,615
# [LOG] step 9080 | train_loss 0.6371 | lr 5.05e-05 | tok/s 35,621
# [LOG] step 9100 | train_loss 0.6279 | lr 5.01e-05 | tok/s 35,618
# [LOG] step 9120 | train_loss 0.6221 | lr 4.97e-05 | tok/s 35,613
# [LOG] step 9140 | train_loss 0.6232 | lr 4.93e-05 | tok/s 35,619
# [LOG] step 9160 | train_loss 0.6293 | lr 4.89e-05 | tok/s 35,620
# [LOG] step 9180 | train_loss 0.6172 | lr 4.85e-05 | tok/s 35,611
# [LOG] step 9200 | train_loss 0.6425 | lr 4.81e-05 | tok/s 35,607
# [LOG] step 9220 | train_loss 0.6246 | lr 4.77e-05 | tok/s 35,602
# [LOG] step 9240 | train_loss 0.6255 | lr 4.73e-05 | tok/s 35,603
# [LOG] step 9260 | train_loss 0.6247 | lr 4.69e-05 | tok/s 35,609
# [LOG] step 9280 | train_loss 0.6283 | lr 4.66e-05 | tok/s 35,610
# [LOG] step 9300 | train_loss 0.6174 | lr 4.62e-05 | tok/s 35,605
# [EVAL] step 9300 | val_loss 0.6631
# [LOG] step 9320 | train_loss 0.6260 | lr 4.58e-05 | tok/s 28,109
# [LOG] step 9340 | train_loss 0.6243 | lr 4.55e-05 | tok/s 35,611
# [LOG] step 9360 | train_loss 0.6236 | lr 4.51e-05 | tok/s 35,613
# [LOG] step 9380 | train_loss 0.6257 | lr 4.47e-05 | tok/s 35,601
# [LOG] step 9400 | train_loss 0.6177 | lr 4.44e-05 | tok/s 35,607
# [LOG] step 9420 | train_loss 0.6183 | lr 4.40e-05 | tok/s 35,623
# [LOG] step 9440 | train_loss 0.6176 | lr 4.37e-05 | tok/s 35,605
# [LOG] step 9460 | train_loss 0.6194 | lr 4.33e-05 | tok/s 35,615
# [LOG] step 9480 | train_loss 0.6192 | lr 4.30e-05 | tok/s 35,622
# [LOG] step 9500 | train_loss 0.6231 | lr 4.27e-05 | tok/s 35,621
# [LOG] step 9520 | train_loss 0.6175 | lr 4.23e-05 | tok/s 35,613
# [LOG] step 9540 | train_loss 0.6219 | lr 4.20e-05 | tok/s 35,612
# [LOG] step 9560 | train_loss 0.6178 | lr 4.17e-05 | tok/s 35,611
# [LOG] step 9580 | train_loss 0.6133 | lr 4.14e-05 | tok/s 35,610
# [LOG] step 9600 | train_loss 0.6206 | lr 4.11e-05 | tok/s 35,603
# [EVAL] step 9600 | val_loss 0.6646
# [LOG] step 9620 | train_loss 0.6207 | lr 4.07e-05 | tok/s 28,635
# [LOG] step 9640 | train_loss 0.6278 | lr 4.04e-05 | tok/s 35,604
# [LOG] step 9660 | train_loss 0.6359 | lr 4.01e-05 | tok/s 35,613
# [LOG] step 9680 | train_loss 0.6273 | lr 3.98e-05 | tok/s 35,609
# [LOG] step 9700 | train_loss 0.6273 | lr 3.96e-05 | tok/s 35,606
# [LOG] step 9720 | train_loss 0.6274 | lr 3.93e-05 | tok/s 35,621
# [LOG] step 9740 | train_loss 0.6221 | lr 3.90e-05 | tok/s 35,618
# [LOG] step 9760 | train_loss 0.6204 | lr 3.87e-05 | tok/s 35,613
# [LOG] step 9780 | train_loss 0.6171 | lr 3.84e-05 | tok/s 35,604
# [LOG] step 9800 | train_loss 0.6058 | lr 3.82e-05 | tok/s 35,604
# [LOG] step 9820 | train_loss 0.6137 | lr 3.79e-05 | tok/s 35,604
# [LOG] step 9840 | train_loss 0.6189 | lr 3.76e-05 | tok/s 35,606
# [LOG] step 9860 | train_loss 0.6141 | lr 3.74e-05 | tok/s 35,605
# [LOG] step 9880 | train_loss 0.6232 | lr 3.71e-05 | tok/s 35,605
# [LOG] step 9900 | train_loss 0.6218 | lr 3.69e-05 | tok/s 35,606
# [EVAL] step 9900 | val_loss 0.6504
# [CKPT] saved FULL /content/drive/MyDrive/MusicScalingProject/runs/V3_best_150M/checkpoints/full_step_0009900.pt
# [LOG] step 9920 | train_loss 0.6199 | lr 3.66e-05 | tok/s 22,590
# [LOG] step 9940 | train_loss 0.6227 | lr 3.64e-05 | tok/s 35,611
# [LOG] step 9960 | train_loss 0.6250 | lr 3.61e-05 | tok/s 35,611
# [LOG] step 9980 | train_loss 0.6153 | lr 3.59e-05 | tok/s 35,623
# [LOG] step 10000 | train_loss 0.6215 | lr 3.57e-05 | tok/s 35,624
# [LOG] step 10020 | train_loss 0.6158 | lr 3.55e-05 | tok/s 35,620
# [LOG] step 10040 | train_loss 0.6143 | lr 3.52e-05 | tok/s 35,629
# [LOG] step 10060 | train_loss 0.6295 | lr 3.50e-05 | tok/s 35,633
# [LOG] step 10080 | train_loss 0.6177 | lr 3.48e-05 | tok/s 35,627
# [LOG] step 10100 | train_loss 0.6160 | lr 3.46e-05 | tok/s 35,616
# [LOG] step 10120 | train_loss 0.6209 | lr 3.44e-05 | tok/s 35,612
# [LOG] step 10140 | train_loss 0.6258 | lr 3.42e-05 | tok/s 35,622
# [LOG] step 10160 | train_loss 0.6170 | lr 3.40e-05 | tok/s 35,609
# [LOG] step 10180 | train_loss 0.6089 | lr 3.38e-05 | tok/s 35,630
# [LOG] step 10200 | train_loss 0.6079 | lr 3.36e-05 | tok/s 35,623
# [EVAL] step 10200 | val_loss 0.6588
# [LOG] step 10220 | train_loss 0.6003 | lr 3.35e-05 | tok/s 25,486
# [LOG] step 10240 | train_loss 0.6118 | lr 3.33e-05 | tok/s 35,622
# [LOG] step 10260 | train_loss 0.6169 | lr 3.31e-05 | tok/s 35,631
# [LOG] step 10280 | train_loss 0.6079 | lr 3.30e-05 | tok/s 35,623
# [LOG] step 10300 | train_loss 0.6143 | lr 3.28e-05 | tok/s 35,616
# [LOG] step 10320 | train_loss 0.6171 | lr 3.26e-05 | tok/s 35,600
# [LOG] step 10340 | train_loss 0.6188 | lr 3.25e-05 | tok/s 35,608
# [LOG] step 10360 | train_loss 0.6064 | lr 3.23e-05 | tok/s 35,625
# [LOG] step 10380 | train_loss 0.6044 | lr 3.22e-05 | tok/s 35,606
# [LOG] step 10400 | train_loss 0.6104 | lr 3.21e-05 | tok/s 35,627
# [LOG] step 10420 | train_loss 0.6209 | lr 3.19e-05 | tok/s 35,615
# [LOG] step 10440 | train_loss 0.6174 | lr 3.18e-05 | tok/s 35,616
# [LOG] step 10460 | train_loss 0.6194 | lr 3.17e-05 | tok/s 35,615
# [LOG] step 10480 | train_loss 0.6158 | lr 3.15e-05 | tok/s 35,617
# [LOG] step 10500 | train_loss 0.6082 | lr 3.14e-05 | tok/s 35,607
# [EVAL] step 10500 | val_loss 0.6636
# [CKPT] saved FULL /content/drive/MyDrive/MusicScalingProject/runs/V3_best_150M/checkpoints/full_step_0010500.pt
# [SAMPLE] wrote /content/drive/MyDrive/MusicScalingProject/runs/V3_best_150M/samples/sample_step_0010500.abc
# [LOG] step 10520 | train_loss 0.6103 | lr 3.13e-05 | tok/s 20,263
# [LOG] step 10540 | train_loss 0.6124 | lr 3.12e-05 | tok/s 35,608
# [LOG] step 10560 | train_loss 0.6081 | lr 3.11e-05 | tok/s 35,606
# [LOG] step 10580 | train_loss 0.6037 | lr 3.10e-05 | tok/s 35,633
# [LOG] step 10600 | train_loss 0.6194 | lr 3.09e-05 | tok/s 35,605
# [LOG] step 10620 | train_loss 0.6167 | lr 3.08e-05 | tok/s 35,623
# [LOG] step 10640 | train_loss 0.6061 | lr 3.07e-05 | tok/s 35,613
# [LOG] step 10660 | train_loss 0.6174 | lr 3.07e-05 | tok/s 35,603
# [LOG] step 10680 | train_loss 0.6128 | lr 3.06e-05 | tok/s 35,627
# [LOG] step 10700 | train_loss 0.6159 | lr 3.05e-05 | tok/s 35,628
# [LOG] step 10720 | train_loss 0.6082 | lr 3.05e-05 | tok/s 35,637
# [LOG] step 10740 | train_loss 0.6156 | lr 3.04e-05 | tok/s 35,613
# [LOG] step 10760 | train_loss 0.6122 | lr 3.03e-05 | tok/s 35,632
# [LOG] step 10780 | train_loss 0.6106 | lr 3.03e-05 | tok/s 35,610
# [LOG] step 10800 | train_loss 0.6100 | lr 3.02e-05 | tok/s 35,610
# [EVAL] step 10800 | val_loss 0.6554
# [LOG] step 10820 | train_loss 0.6087 | lr 3.02e-05 | tok/s 29,249
# [LOG] step 10840 | train_loss 0.6100 | lr 3.01e-05 | tok/s 35,613
# [LOG] step 10860 | train_loss 0.6107 | lr 3.01e-05 | tok/s 35,611
# [LOG] step 10880 | train_loss 0.6021 | lr 3.01e-05 | tok/s 35,613
# [LOG] step 10900 | train_loss 0.6114 | lr 3.01e-05 | tok/s 35,612
# [LOG] step 10920 | train_loss 0.6114 | lr 3.00e-05 | tok/s 35,611
# [LOG] step 10940 | train_loss 0.6061 | lr 3.00e-05 | tok/s 35,611
# [LOG] step 10960 | train_loss 0.6172 | lr 3.00e-05 | tok/s 35,612
# [LOG] step 10980 | train_loss 0.6066 | lr 3.00e-05 | tok/s 35,610
# [LOG] step 11000 | train_loss 0.6052 | lr 3.00e-05 | tok/s 35,611
# [CKPT] saved FULL /content/drive/MyDrive/MusicScalingProject/runs/V3_best_150M/checkpoints/full_step_0011000.pt
# [DONE]
